# %%
import matplotlib.pyplot as pit

x= [1,2,3,4,5]
y = [1,4,9,16,25]

# create a line plot

pit.plot(x,y)
pit.xlabel('X axis')
pit.ylabel('Y axis')
pit.title('Basic line plot')
# Out:
# Text(0.5, 1.0, 'Basic line plot')
